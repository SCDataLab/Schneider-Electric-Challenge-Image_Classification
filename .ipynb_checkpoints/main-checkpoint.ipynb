# %%
#Importing necessary libraries 
import os
import cv2
import numpy as np
import pandas as pd 
import tensorflow as tf


import matplotlib.pyplot as plt
plt.style.use('bmh')

from keras import backend as K
from keras.models import Sequential
from keras.utils import to_categorical
from keras.optimizers import SGD,RMSprop
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D,BatchNormalization

from sklearn.model_selection import train_test_split

import random

# %%
#functions that will be needed later
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
#(1) Some initilisations
df_training_file = r'../../challenge_files/train.csv'
df_testing_file = r'../../challenge_files/test.csv'
img_col_name_name_in_training_file = 'example_path'
class_col_name_in_training_file = 'label'
training_images_directory = r'../../challenge_files/train_test_data/train/'

# %%
#(2) Reading and preparing the training dataframe file

df = pd.read_csv(df_training_file)

#Convert the class column into strings
df.loc[:,class_col_name_in_training_file] = df.loc[:,class_col_name_in_training_file].astype(str)

#Keep only the basenames of the files in the example_path column
df.loc[:,img_col_name_name_in_training_file] = df.loc[:,img_col_name_name_in_training_file].apply(lambda x: os.path.basename(x))

df.head()
# Out:
#   label  latitude   longitude  year example_path
# 0     0 -2.051853  111.826093  2001     1297.png
# 1     2 -1.989349  105.309496  2013     1199.png
# 2     0  1.223256  100.702217  2014     1348.png
# 3     0 -2.342948  103.890226  2008     2214.png
# 4     0 -0.126555  101.758175  2011     2220.png

# %%
# (3) Print a summary information about the number of training images per class
unique, counts = np.unique(np.array(df.loc[:,class_col_name_in_training_file]),return_counts=True)
percentage = round(counts/len(df),2)
counts_df = pd.DataFrame(zip(unique,counts,percentage), columns=['class','count','percentage'])
display(counts_df)
# Out:
#   class  count  percentage
# 0     0    860    0.501750
# 1     1    196    0.114352
# 2     2    658    0.383897

# %%
# Some notes:
# -----------
# - It seems that the training dataset is imbalanced. 
# class 1 seems to be the most under-represented
# 
# - We can use augmentation to balance the classes

# %%
# (4) Balance the dataset

bal_img_gen = ImageDataGenerator(
        rotation_range=10, # rotation
        horizontal_flip=True, # horizontal flip
        vertical_flip=True) # vertical flip


# balancing class 1
num_required_augmnetations_for_class1= int(counts_df.loc[counts_df['class']=='0','count']) - int(counts_df.loc[counts_df['class']=='1','count'])
df_class1 = df.loc[df[class_col_name_in_training_file]=="1",:]

"""
#apply some augmentation on that class of images
for x, val in zip(bal_img_gen.flow_from_dataframe(dataframe=df_class1, 
                                          directory=training_images_directory,
                                          x_col=img_col_name_name_in_training_file, 
                                          y_col=class_col_name_in_training_file, 
                                          class_mode="categorical", 
                                          target_size=(332, 332), 
                                          save_to_dir=r"../../challenge_files/test_aug/class1/",
                                          save_prefix='class_1_aug',        # it will save the images as 'aug_0912' some number for every new augmented image
                                          save_format='png',
                                          batch_size=1,
                                          rescale=1.0/255,
                                          seed=2021),range(num_required_augmnetations_for_class1)):
    pass

"""
# balancing class 2
num_required_augmnetations_for_class2= int(counts_df.loc[counts_df['class']=='0','count']) - int(counts_df.loc[counts_df['class']=='2','count'])
df_class2 = df.loc[df[class_col_name_in_training_file]=="2",:]

#apply some augmentation on that class of images
for x, val in zip(bal_img_gen.flow_from_dataframe(dataframe=df_class2, 
                                          directory=training_images_directory,
                                          x_col=img_col_name_name_in_training_file, 
                                          y_col=class_col_name_in_training_file, 
                                          class_mode="categorical", 
                                          target_size=(332, 332), 
                                          save_to_dir=r"../../challenge_files/test_aug/class2/",
                                          save_prefix='class_2_aug',        # it will save the images as 'aug_0912' some number for every new augmented image
                                          save_format='png',
                                          batch_size=1,
                                          rescale=1.0/255,
                                          seed=2021),range(num_required_augmnetations_for_class2)):
    pass
# Out:
# Found 658 validated image filenames belonging to 1 classes.

# %%
# (4) Deciding the augmentations to apply to the images.

datagen = ImageDataGenerator(
        rotation_range=10, # rotation
        horizontal_flip=True, # horizontal flip
        brightness_range=[3,5]) # brightness (images as submitted are quite dark)


#Let the augmentation flow to be from a dataframe
train_generator_df = datagen.flow_from_dataframe(dataframe=df, 
                                              directory=training_images_directory,
                                              x_col=img_col_name_name_in_training_file, 
                                              y_col=class_col_name_in_training_file, 
                                              class_mode="categorical", 
                                              target_size=(200, 200), 
                                              batch_size=1,
                                              rescale=1.0/255,
                                              seed=2021)

#Plotting images
fig, ax = plt.subplots(nrows=5, ncols=4, figsize=(15,15))
ax = ax.flatten()

for i in range(20):
    # convert to unsigned integers for plotting
    image = next(train_generator_df)[0].astype('uint8')
    
    # changing size from (1, 200, 200, 3) to (200, 200, 3) for plotting the image
    image = np.squeeze(image)
    
    # plot raw pixel data
    ax[i].imshow(image)
    ax[i].axis('off')
# Out:
# Found 1714 validated image filenames belonging to 3 classes.

# %%
# (5) Split data into train-test data sets

X = df.loc[:,img_col_name_name_in_training_file]
y = df.loc[:,class_col_name_in_training_file]

# Split
train_x, val_x, train_y, val_y = train_test_split(X, y, 
                                              test_size = 0.2, 
                                              random_state = 27, 
                                              stratify=y)

# Train df
df_train = pd.DataFrame(columns=['image_name','category'])
df_train['image_name'] = train_x
df_train['category'] = train_y

# Test df
df_test= pd.DataFrame(columns=['image_name','category'])
df_test['image_name'] = val_x
df_test['category'] = val_y

df_train.reset_index(drop=True, inplace=True)
df_test.reset_index(drop=True, inplace=True)

#display(df_train.head())
#display(df_test.head())

print(df.shape)
print(df_train.shape)
print(df_test.shape)
# Out:
# (1714, 5)
# (1371, 2)
# (343, 2)

# %%
# (6) Append images into a list and prepare them to be input to the model.

# Images
train_images = df_train.loc[:,'']
train_labels = df_train.loc[:,'category']

test_images = df_test.loc[:,'image_name']
test_labels = df_test.loc[:,'category']

# Train images
x_train = []
for i in train_images:
    image_path = os.path.abspath(os.path.join(training_images_directory,str(i)))
    img = cv2.imread(image_path)
    x_train.append(img)

# Train labels
y_train= to_categorical(train_labels)

# Test images
x_test = []
for i in test_images:
    image_path = os.path.abspath(os.path.join(training_images_directory,str(i)))
    img = cv2.imread(image_path)
    x_test.append(img)

# Test labels
y_test=to_categorical(test_labels)

# Normalize images
x_train = np.array(x_train, dtype="float") / 255.0
x_test = np.array(x_test, dtype="float") / 255.0

# %%
img.shape
# Out:
# (332, 332, 3)

# %%
# (7) Building the model
#Let’s create the architecture for our CNN model. 
# Three Convolutional layers and two fully connected layers.

model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape=(332, 332, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.24))
model.add(Dense(3,activation='softmax'))


# Compile
optim = RMSprop(learning_rate=0.00001)
model.compile(loss='categorical_crossentropy',
              optimizer=optim,
              metrics=['acc',f1_m,precision_m, recall_m])
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_21 (Conv2D)          (None, 330, 330, 32)      896
#
#  max_pooling2d_21 (MaxPoolin  (None, 165, 165, 32)     0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 163, 163, 32)      9248
#
#  max_pooling2d_22 (MaxPoolin  (None, 81, 81, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 79, 79, 64)        18496
#
#  max_pooling2d_23 (MaxPoolin  (None, 39, 39, 64)       0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 97344)             0
#
#  dense_14 (Dense)            (None, 64)                6230080
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_15 (Dense)            (None, 3)                 195
#
# ...
# Total params: 6,258,915
# Trainable params: 6,258,915
# Non-trainable params: 0
# _________________________________________________________________

# %%
# (8) Train first without augmnetaiton to check
epochs = 25
# Fit
history = model.fit(x_train,y_train,
                    epochs=epocks,
                    validation_data=(x_test,y_test),
                    batch_size=32,
                    verbose=1)
# Out:
# Epoch 1/25
# 43/43 [==============================] - 59s 1s/step - loss: 0.9820 - acc: 0.4894 - f1_m: 0.1673 - precision_m: 0.4313 - recall_m: 0.1193 - val_loss: 0.9503 - val_acc: 0.5015 - val_f1_m: 0.3716 - val_precision_m: 0.6080 - val_recall_m: 0.2726
# Epoch 2/25
# 43/43 [==============================] - 56s 1s/step - loss: 0.9487 - acc: 0.5004 - f1_m: 0.3597 - precision_m: 0.5479 - recall_m: 0.2736 - val_loss: 0.9487 - val_acc: 0.5015 - val_f1_m: 0.4202 - val_precision_m: 0.5401 - val_recall_m: 0.3458
# Epoch 3/25
# 43/43 [==============================] - 55s 1s/step - loss: 0.9528 - acc: 0.4843 - f1_m: 0.3581 - precision_m: 0.5373 - recall_m: 0.2774 - val_loss: 0.9474 - val_acc: 0.5015 - val_f1_m: 0.3868 - val_precision_m: 0.5753 - val_recall_m: 0.2953
# Epoch 4/25
# ...

# %%
training_f1_score = history.history['f1_m']
validation_f1_score = history.history['val_f1_m']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(epochs)

fig, axis = plt.subplots(1,2,figsize=(15, 5))

axis[0].plot(epochs_range,training_f1_score, label= 'Training f1 score')
axis[0].plot(epochs_range,validation_f1_score, label= 'Validation f1 score')
axis[0].legend(fontsize=15)

axis[1].plot(epochs_range,loss, label= 'Training loss')
axis[1].plot(epochs_range,val_loss, label= 'Validation loss')
axis[1].legend(fontsize=15)

# %%
# (8) Train with augmnetaiton to see if there is any improvment
epochs = 25

img_data_gen = ImageDataGenerator(
        rotation_range=10, # rotation
        horizontal_flip=True, # horizontal flip
        brightness_range=[3,5]) # brightness (images as submitted are quite dark)


generator_for_training_df = img_data_gen.flow_from_dataframe(dataframe=df_train, 
                                              directory=training_images_directory,
                                              x_col='image_name', 
                                              y_col='category', 
                                              class_mode="categorical", 
                                              target_size=(332, 332), 
                                              batch_size=1,
                                              rescale=1.0/255,
                                              seed=2021)

generator_for_validation_df = img_data_gen.flow_from_dataframe(dataframe=df_test, 
                                              directory=training_images_directory,
                                              x_col='image_name', 
                                              y_col='category', 
                                              class_mode="categorical", 
                                              target_size=(332, 332), 
                                              batch_size=1,
                                              rescale=1.0/255,
                                              seed=2021)

history_aug = model.fit(generator_for_training_df,
                        epochs=epochs,
                        validation_data=generator_for_validation_df,
                        batch_size=32,
                        verbose=1)
# Out:
# Found 1371 validated image filenames belonging to 3 classes.
# Found 343 validated image filenames belonging to 3 classes.
# Epoch 1/25
# 1371/1371 [==============================] - 181s 132ms/step - loss: 1.5117 - acc: 0.4522 - f1_m: 0.2086 - precision_m: 0.2086 - recall_m: 0.2086 - val_loss: 1.0537 - val_acc: 0.4548 - val_f1_m: 0.0525 - val_precision_m: 0.0525 - val_recall_m: 0.0525
# Epoch 2/25
# 1371/1371 [==============================] - 192s 140ms/step - loss: 1.0566 - acc: 0.4726 - f1_m: 0.2414 - precision_m: 0.2414 - recall_m: 0.2414 - val_loss: 1.0327 - val_acc: 0.4548 - val_f1_m: 0.0904 - val_precision_m: 0.0904 - val_recall_m: 0.0904
# Epoch 3/25
# 1371/1371 [==============================] - 206s 150ms/step - loss: 1.0108 - acc: 0.4646 - f1_m: 0.2524 - precision_m: 0.2524 - recall_m: 0.2524 - val_loss: 1.0487 - val_acc: 0.5190 - val_f1_m: 0.3207 - val_precision_m: 0.3207 - val_recall_m: 0.3207
# Epoch 4/25
# ...

# %%
training_f1_score = history_aug.history['f1_m']
validation_f1_score = history_aug.history['val_f1_m']
loss=history_aug.history['loss']
val_loss=history_aug.history['val_loss']

epochs_range = range(epochs)

fig2, axis2 = plt.subplots(1,2,figsize=(15, 5))

axis2[0].plot(epochs_range,training_f1_score, label= 'Training f1 score')
axis2[0].plot(epochs_range,validation_f1_score, label= 'Validation f1 score')
axis2[0].legend(fontsize=15)

axis2[1].plot(epochs_range,loss, label= 'Training loss')
axis2[1].plot(epochs_range,val_loss, label= 'Validation loss')
axis2[1].legend(fontsize=15)
